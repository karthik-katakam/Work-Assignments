# %% [markdown]
# ## Strings
#
# ### Properties :
# - Immutable
# - Can be concatenated

# %%
'String'
# Out:
# 'String'

# %%
"String"
# Out:
# 'String'

# %%
"S'tring"
# Out:
# "S'tring"

# %%
print("s \nnss")
# Out:
# s
# nss

# %%
a='string'
len(a)
# Out:
# 6

# %%
# Indexing starts from 0 NOT 1
a[0]
# Out:
# 's'

# %%
a[:3]
# Out:
# 'str'

# %%
a[3:]
# Out:
# 'ing'

# %%
a[::3] #3 is the step Size
# Out:
# 'si'

# %%
a[::-1]
# Out:
# 'gnirts'

# %% [markdown]
# ## Builtin Methods
# - upper , isupper (Returns True or False)
# - lower , islower (Returns True or False)
# - split #Parameter used to split is removed during spliting
# - partition #uses first occurence of the parameter passed
# - count
# - find
# - isalnum
# - isspace
# - endswith
# - istitle staring letter is caps

# %%
a="Python Training"

# %%
a.upper()
# Out:
# 'PYTHON TRAINING'

# %%
a.lower()
# Out:
# 'python training'

# %%
a.split()
# Out:
# ['Python', 'Training']

# %%
a.split('n')
# Out:
# ['Pytho', ' Trai', 'i', 'g']

# %%
a.isalnum()
# Out:
# False

# %%
a.isspace()
# Out:
# False

# %%
a.endswith('g')
# Out:
# True

# %%
a.istitle()
# Out:
# True

# %% [markdown]
# ## Lists
# - Stores mutilple data points , and different data types
# - mutable
# - concatenation but while doing we need to reassign the variable

# %%
l=["k",1]

# %%
l
# Out:
# ['k', 1]

# %%
l[1]=2

# %%
l
# Out:
# ['k', 2]

# %%
p=l+[1]

# %%
p
# Out:
# ['k', 2, 1]

# %% [markdown]
# ### Nested List

# %%
l=[[1,2],[3,4],[5,6]]

# %%
l
# Out:
# [[1, 2], [3, 4], [5, 6]]

# %%
l[1]
# Out:
# [3, 4]

# %%
l[1][1]
# Out:
# 4

# %% [markdown]
# ## BuiltIn Methods
# - append
# - pop LIFO
# - reverse
# - append
# - extend

# %%
l.append(5)

# %%
l
# Out:
# [2, 5, 5]

# %%
l.pop(0)
# Out:
# 2

# %%
l
# Out:
# [5, 5]

# %%
l.pop()
# Out:
# 5

# %%
l=l+[1,2,3]

# %%
l
# Out:
# [5, 1, 2, 3]

# %%
l.sort()

# %%
l
# Out:
# [1, 2, 3, 5]

# %%
l.reverse()

# %%
l
# Out:
# [5, 3, 2, 1]

# %%
l = [1,2,3]

# %%
l.append([1,2])

# %%
l
# Out:
# [1, 2, 3, [1, 2]]

# %%
l.extend([1,2])

# %%
l
# Out:
# [1, 2, 3, 1, 2]

# %% [markdown]
# ### List Comprension

# %%
l=[[1,2],[3,4],[5,6]]

# %%
t=[i[0] for i in l]

# %%
t
# Out:
# [1, 3, 5]

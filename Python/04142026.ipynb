# %% [markdown]
# # Tuples
# - Imutable
# - can hold different datatypes
# - .index() to return index value of the passed paramater
# - count() returns the count how many times it is occuring in the tuple
# - Mainly used to provide data integrity

# %%
t = (1,2,3)

# %%
t
# Out:
# (1, 2, 3)

# %%
t.index(1)
# Out:
# 0

# %%
t.count(1)
# Out:
# 1

# %%
t[0] = 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 t[0] = 2
#
# TypeError: 'tuple' object does not support item assignment

# %%
t=('Kiri',1,3)
print(type(t))
# Out:
# <class 'tuple'>

# %%
l=list(t)
print(type(l))
# Out:
# <class 'list'>

# %%
l
# Out:
# ['Kiri', 1, 3]

# %%
l.append(4)

# %%
t=tuple(l)
print(type(t))
# Out:
# <class 'tuple'>

# %%
t
# Out:
# ('Kiri', 1, 3, 4)

# %% [markdown]
# # Sets
# - Unordered collection of unqiue elements
# - discard , remove does the same work but discard is a safe removal even if the data is present or not it will not throw error.
# - Set is mutable

# %%
s = set()

# %%
s.add(2)

# %%
s
# Out:
# {2}

# %%
s.add("karthik")

# %%
s.add(5)

# %%
s.add(1)

# %%
s
# Out:
# {1, 2, 5, 'karthik'}

# %%
s.discard('karthik')

# %%
s.remove(1)

# %%
s
# Out:
# {2, 5}

# %%
s.pop()
# Out:
# 2

# %%
s
# Out:
# {5}

# %%
l=[1,2,3,4,5,6,7,7]

# %%
s=set(l)

# %% [markdown]
# # Dictionaries
